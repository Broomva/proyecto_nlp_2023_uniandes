# %%
# !pip install -q -U transformers datasets accelerate peft trl bitsandbytes wandb

# %%
source_lang, source_lang_iso = "Spanish", "spa"
target_lang, target_lang_iso = "Wayuu", "guc" # or pbb

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    AutoTokenizer,
    TrainingArguments,
    pipeline,
)
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training
from trl import SFTTrainer
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(

# %% [markdown]
# Load Fine Tuned model

# %%
# Model
base_model = f"Broomva/llama-2-7b-chat-instruct-translate-{source_lang_iso}-{target_lang_iso}"

# Tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, use_fast=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %% [markdown]
# Quantize model

# %%
# Quantization configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

# LoRA configuration
peft_config = LoraConfig(
    lora_alpha=32,
    lora_dropout=0.05,
    r=16,
    bias="none",
    task_type="CAUSAL_LM",
)

# Load base moodel
model = AutoModelForCausalLM.from_pretrained(
    base_model,
    quantization_config=bnb_config,
)

# Cast the layernorm in fp32, make output embedding layer require grads, add the upcasting of the lmhead to fp32
model = prepare_model_for_kbit_training(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:381: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:386: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(

# %%
def translate(spanish_prompt, wayuu_reference):
  instruction = f"<s>[INST] Traduce de {source_lang} a {target_lang}: {spanish_prompt} [/INST]"
  pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=len(instruction)+len(wayuu_reference))
  result = pipe(instruction)
  return result[0]['generated_text'][len(instruction):]

# %%
import pandas as pd

dataset = pd.read_csv(f'../datasets/{source_lang_iso}_{target_lang_iso}/{source_lang_iso}_{target_lang_iso}_dataset.csv', sep = '|').sample(50)
source_sentences = dataset[source_lang_iso]
target_references = dataset[target_lang_iso]

# %%
model_outputs = [translate(source_sentence, target_reference) for source_sentence, target_reference in zip(source_sentences, target_references)]
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(

# %%
results_df = pd.DataFrame({source_lang_iso: list(source_sentences), target_lang_iso: list(target_references), f'generated_{target_lang_iso}': model_outputs})
results_df.head(20)
# Out:
#                                                   spa  \
# 0      Pero ¿qué representa el que se lavara a Aarón?
# 1                                         que hace el
# 2   ¿Qué ayuda práctica podría usted dar a alguien...
# 3                                   tom salio a comer
# 4   14 Muchos hermanos viven en países donde los p...
# 5   Al ver que estaba resentido, Rutherford le adv...
# 6                                       quieres comer
# 7                                              entren
# 8   Despertó su entusiasmo por lo que podrían logr...
# 9                              ella puede saltar alto
# 10  sus hermosas ilustraciones e instructivos diag...
# 11  en este articulo estudiaremos su humildad y co...
# 12  tambien expreso su afecto por la madre de rufo...
# 13                                  comienza a cantar
# 14                          tengo que comprar zapatos
# 15                         deberiamos adorar imagenes
# 16                                             pierce
# 17  El Diablo recurrió a los tres cuando tentó a J...
# 18  Por ejemplo, en marzo de 2011, un terremoto y ...
# 19  ¿Por qué los niños vivían de un modo especial ...
#
#                                                   guc  \
# 0   Oʼoojinnüshi Aarón süpülapünaa sacerdooteinjac...
# 1                             kasa naa'inraaka niakai
# 2   ¿Kasa paaʼinrajatka süpüla pükaaliinjüin na aa...
# 3                            ajuittüshi tom ekaainchi
# 4   14 Mainma wawalayuu eʼrakana müliaa otta choʼu...
# 5   Sutuma jashichin nia, nüküjüin Rutherford eein...
# 6                                         ekeeshi pia
# 7                                              joutaa
# 8   Je tü naaʼinreetkat, alanaʼaleejeeria sünain a...
# 9              shiaka sütüjain awataa iipünaashaatasü
# 10  shikirajaainjatü anain wayuu süpüla su'waajüin...
# 11  kasa naa'inraka jesuu süpüla nii'iyatüin sünai...
# 12  tü nüküjeekat pablo shia ichein nanoula naya w...
# 13                            pu'tta sünain ee'irajaa
# 14                      achekü tayalajüin tajureekase
# 15              wakaaliinja na nuwalayuukana kürisüto
# 16                                             pierce
# 17  Süka tia apünüinsükat kasa ooʼulakünüsü naaʼin...
# 18  Soʼu kashikat maatsoʼu 2011, ouktüshii wainma ...
# 19  ¿Jamüsü natüjaainjatka aaʼu nachonnii na israe...
#
#                                         generated_guc
# 0    ¿Kasa kayaawaseka nüshanaain Aarón? 5-7. 5. ¿...
# 1    kasa naa'inraaka niakai sutuma tü nümakat jes...
# 2    ¿Kasa eeka süpüla paaʼinrüin nümüin wanee jim...
# 3    ekaashi tom sünain ekaa ma aka tia so'ukai ji...
# 4    14 Wainma wawalayuu kepiakana sainküin mmakat...
# 5    Nnojoishi niain anain Rutherford sümüin wayuu...
# 6    ekeesü paa'in süpüla shiküinjatüin wayuu shia...
# 7    jaleraa maa'ulu yaa sulu'u ekirajüleeka wayuu...
# 8    Müleka jiküle je jülemerale, shiimüin sünain ...
# 9    shiakalü eesü süpüla sujutuin süpaatiwa sümaa...
# 10   tü pütchi nashajakat süchiki tü kasa nukumaja...
# 11   sünain ekirajaayakat tüü wekirajaajeerü anain...
# 12   aishi nia nüpüla rufo eesüja'a süpüla nümüin ...
# 13   pu'tta sünain ee'irajaa pütuma ee'irajaa müsh...
# 14   acheküsü tayalajüin tajureekase sapataka tüüc...
# 15   jamüshii wa'waajüinjachika saa'u kasa sümaiwa...
# 16   pierce müshi taya saa'in tamüin türa pienchis...
# 17   Niasaʼa chi Yolujaakai, nüchajaain Jesuu pala...
# 18   Soʼu juyaka 2011, ojuʼitüsü wanee juya miyoʼu...
# 19   ¿Jamüshiiche naya süpüla nekirajüinjanain na ...

# %%
from nltk.translate.bleu_score import SmoothingFunction, corpus_bleu

smoothie = SmoothingFunction().method5
bleu_score_smooth = corpus_bleu(target_references, model_outputs, smoothing_function=smoothie)
print(f"Smooth BLEU Score: {bleu_score_smooth}")
# Out:
# 0.07187542180783783

# %%
from nltk.translate.bleu_score import sentence_bleu

# Calculate BLEU for each sentence
individual_bleu_scores = [sentence_bleu([reference], candidate) for reference, candidate in zip(target_references, model_outputs)]
print(f"AVG Sentence BLEU Score: {sum(individual_bleu_scores)/len(individual_bleu_scores)}")
# Out:
# AVG Sentence BLEU Score: 0.13479943753792184
